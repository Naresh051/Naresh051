# %% [markdown]
# <a href="https://colab.research.google.com/github/Naresh051/Naresh051/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is for Humans

# %%
5 + 5
# Out:
# 10

# %%
seconds_in_minute = 60
seconds_in_hour = seconds_in_minute * 60
print(seconds_in_hour)
# Out:
# 3600

# %%
borough = [10, 17, 19, 12]
import random
random.choice(borough)
# Out:
# 10

# %%
import pandas as pd

# %%
df = pd.read_csv('NYPD_Crime.csv')
df.head()
# Out:
#    CMPLNT_NUM  ...                       New Georeferenced Column
# 0   903695881  ...   POINT (-73.90287588699994 40.64564719600002)
# 1   400462399  ...  POINT (-73.78726915499993 40.682499421000045)
# 2   587910690  ...  POINT (-73.79144856999993 40.689218058000044)
# 3   186105368  ...   POINT (-73.88124724999993 40.88271780700006)
# 4   185325394  ...   POINT (-73.77667979199998 40.69648322200004)
#
# [5 rows x 36 columns]

# %%
df.describe()
# Out:
#          CMPLNT_NUM    ADDR_PCT_CD  ...       Latitude      Longitude
# count  4.495060e+05  449506.000000  ...  449506.000000  449506.000000
# mean   5.501311e+08      63.668676  ...      40.736834     -73.923447
# std    2.598030e+08      35.023210  ...       0.082496       0.076968
# min    1.000004e+08       1.000000  ...      40.499401     -74.253767
# 25%    3.250324e+08      40.000000  ...      40.675213     -73.971681
# 50%    5.503056e+08      63.000000  ...      40.735019     -73.926464
# 75%    7.751226e+08     101.000000  ...      40.811485     -73.879894
# max    9.999964e+08     123.000000  ...      40.912723     -73.700568
#
# [8 rows x 10 columns]

# %%
df[['KY_CD','PD_CD']]
# Out:
#         KY_CD  PD_CD
# 0         101    NaN
# 1         101    NaN
# 2         101    NaN
# 3         118  792.0
# 4         101    NaN
# ...       ...    ...
# 449501    578  637.0
# 449502    117  503.0
# 449503    341  333.0
# 449504    578  638.0
# 449505    109  422.0
#
# [449506 rows x 2 columns]

# %%
df.loc[5:10]
# Out:
#     CMPLNT_NUM  ...                      New Georeferenced Column
# 5    791525475  ...  POINT (-73.91529662699998 40.84196981100007)
# 6    276296223  ...  POINT (-73.87712270799993 40.89547629000003)
# 7    600494269  ...  POINT (-73.89925031699994 40.86071697500005)
# 8    477204863  ...  POINT (-73.89200234699997 40.67565718100008)
# 9    528992969  ...  POINT (-73.91153990699996 40.65563971300003)
# 10   824175212  ...  POINT (-73.79753162399999 40.70586500300004)
#
# [6 rows x 36 columns]

# %%
len(df)
# Out:
# 449506

# %%
df[df['BORO_NM']=='BROOKLYN']
# Out:
#         CMPLNT_NUM  ...                       New Georeferenced Column
# 57       911958653  ...   POINT (-73.99452974999997 40.57670315100006)
# 74       958435302  ...   POINT (-73.88691987599998 40.66456888000005)
# 80       135570027  ...         POINT (-73.95574451 40.68151004300007)
# 82       488929658  ...  POINT (-73.86768716899996 40.654916921000044)
# 84       947525695  ...  POINT (-73.91220924599996 40.656411510000055)
# ...            ...  ...                                            ...
# 449494   625326007  ...  POINT (-73.99497819299995 40.644968963000046)
# 449499   909667230  ...   POINT (-74.02728485599994 40.62215389700003)
# 449501   798000815  ...   POINT (-74.00089057799994 40.57600335300003)
# 449502   900510890  ...   POINT (-73.93155521999995 40.69936940200005)
# 449505   806537994  ...   POINT (-73.91070713999993 40.66388988400007)
#
# [126462 rows x 36 columns]

# %%
df['BORO_NM'].value_counts()
# Out:
# BROOKLYN         126462
# MANHATTAN        110655
# QUEENS            98158
# BRONX             94180
# STATEN ISLAND     18900
# Name: BORO_NM, dtype: int64

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon', 'New Georeferenced Column'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449506 entries, 0 to 449505
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CMPLNT_NUM                449506 non-null  int64
#  1   ADDR_PCT_CD               449506 non-null  int64
#  2   BORO_NM                   448355 non-null  object
#  3   CMPLNT_FR_DT              449506 non-null  object
#  4   CMPLNT_FR_TM              449506 non-null  object
#  5   CMPLNT_TO_DT              409416 non-null  object
#  6   CMPLNT_TO_TM              409568 non-null  object
#  7   CRM_ATPT_CPTD_CD          449345 non-null  object
#  8   HADEVELOPT                1577 non-null    object
#  9   HOUSING_PSA               32583 non-null   object
#  10  JURISDICTION_CODE         449023 non-null  float64
#  11  JURIS_DESC                449506 non-null  object
#  12  KY_CD                     449506 non-null  int64
# ...

# %%
df['CMPLNT_FR_TM']
# Out:
# 0         22:13:00
# 1          6:21:00
# 2         20:05:00
# 3         22:49:00
# 4         17:25:00
#             ...
# 449501     7:00:00
# 449502     4:50:00
# 449503     9:35:00
# 449504    19:40:00
# 449505    12:00:00
# Name: CMPLNT_FR_TM, Length: 449506, dtype: object

# %%
import seaborn as sns

# %%
sns.countplot(data=df, x ='BORO_NM')

# %%
sns.scatterplot(data=df, x= 'Longitude', y= 'Latitude', hue = 'LAW_CAT_CD', style = 'LAW_CAT_CD')
